# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import re
import statistics

# %%
df = pd.read_csv("Data_mypham_Tpcn.csv")
df.head(60)
# Out:
#                                          Product Name  \
# 0   Viên uống Golex Ocavill hỗ trợ chống lại sự ph...
# 1   Siro Bổ Phế Lábebé 120ml hỗ trợ bổ phế, giảm h...
# 2   Siro ống uống Canxi-D3-K2 5ml Kingphar bổ sung...
# 3   Siro Brauer Baby Kids D3+k2 High Potency MK-7 ...
# 4   Thực phẩm bảo vệ sức khỏe KID GROW Kenko tăng ...
# 5   Thực phẩm bảo vệ sức khỏe OMEGA 3 PLUS Kenko h...
# 6   Viên uống Omexxel Ginkgo 120 Premium Omexxel h...
# 7   Viên uống SkillMax Ocavill hỗ trợ tăng cường t...
# 8   Viên uống Pikolin Ocavill hỗ trợ tăng tuần hoà...
# 9   Viên nhai Borne Mineral New Nordic hỗ trợ phát...
# 10  Thực phẩm bảo vệ sức khỏe Calcium Premium Jpan...
# 11  Viên uống Rama Bổ Phổi hỗ trợ bổ phổi, giảm ho...
# 12  Viên uống hỗ trợ phụ nữ mang thai và phụ nữ ch...
# 13  Viên sủi Kudos Kids Multivitamins Plus Calcium...
# 14  Viên sủi Kudos Daily Vitamins Plus Biotin & Gi...
# 15  Viên sủi Kudos Vitamin C 1000mg hương chanh gi...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  1485 non-null   object
#  1   Category      1485 non-null   object
#  2   Dosage Form   1101 non-null   object
#  3   Price         1485 non-null   float64
#  4   Trademark     1376 non-null   object
#  5   Brand Origin  1427 non-null   object
#  6   Country       1481 non-null   object
#  7   Rating        1024 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 92.9+ KB

# %%
for col in df.columns:
    print(type(df[col][0]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.float64'>

# %%
cate = []
for val in df['Category']:
    cate.append(re.split(', | &', val))
    
df['Chuc nang'] = cate
df.head()
# Out:
#                                         Product Name  \
# 0  Viên uống Golex Ocavill hỗ trợ chống lại sự ph...
# 1  Siro Bổ Phế Lábebé 120ml hỗ trợ bổ phế, giảm h...
# 2  Siro ống uống Canxi-D3-K2 5ml Kingphar bổ sung...
# 3  Siro Brauer Baby Kids D3+k2 High Potency MK-7 ...
# 4  Thực phẩm bảo vệ sức khỏe KID GROW Kenko tăng ...
#
#                          Category     Dosage Form     Price Trademark  \
# 0           Thận, tiền liệt tuyến        Viên nén  495000.0   OCAVILL
# 1    Tăng sức đề kháng, miễn dịch            Siro   75000.0       NaN
# 2       Bổ sung Canxi & Vitamin D        Hỗn dịch  105000.0  Kingphar
# 3           Vitamin & Khoáng chất  Dung dịch uống  396000.0    Brauer
# 4  Cải thiện tăng cường chức năng            Siro  480000.0     KENKO
#
#   Brand Origin   Country  Rating                         Chuc nang
# 0          Anh       Anh     5.0           [Thận, tiền liệt tuyến]
# 1     Việt Nam  Việt Nam     5.0    [Tăng sức đề kháng, miễn dịch]
# ...

# %%
del df['Category']

# %%
df
# Out:
#                                            Product Name     Dosage Form  \
# 0     Viên uống Golex Ocavill hỗ trợ chống lại sự ph...        Viên nén
# 1     Siro Bổ Phế Lábebé 120ml hỗ trợ bổ phế, giảm h...            Siro
# 2     Siro ống uống Canxi-D3-K2 5ml Kingphar bổ sung...        Hỗn dịch
# 3     Siro Brauer Baby Kids D3+k2 High Potency MK-7 ...  Dung dịch uống
# 4     Thực phẩm bảo vệ sức khỏe KID GROW Kenko tăng ...            Siro
# ...                                                 ...             ...
# 1480  Kem ngừa mụn ban đêm Canova Acnell Sifarma giú...             NaN
# 1481  Kem dưỡng giảm đốm nâu Eucerin Even Skin Spotl...             NaN
# 1482  Sữa rửa mặt dịu nhẹ sáng da Eucerin Spotless B...             NaN
# 1483  Sữa dưỡng thể trắng da Eucerin Even Skin Spotl...             NaN
# 1484  Kem dưỡng sáng da ban đêm Eucerin Even Skin Sp...        Dạng kem
#
#          Price Trademark Brand Origin   Country  Rating  \
# ...

# %%
df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop_duplicates()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:6818, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6815 inplace = validate_bool_kwarg(inplace, "inplace")
#    6816 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6818 result = self[-self.duplicated(subset, keep=keep)]
#    6819 if ignore_index:
#    6820     result.index = default_index(len(result))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:6958, in DataFrame.duplicated(self, subset, keep)
#    6956 else:
# ...
