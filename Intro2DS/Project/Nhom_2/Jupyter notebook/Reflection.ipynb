# %% [markdown]
# # **REFLECTION**

# %% [markdown]
# ### **1. What diffulties have you encounted?**

# %% [markdown]
# - **Liên Hoa**: During the project, I found it difficult to find features from the Long Chau Pharmacy website for analysis. This made it difficult for me in particular and the team members in general to explore and use the collected features to ask meaningful questions for the selected topic. Personally, I also found it difficult to find a model that fits our dataset.
# - **Duy Hưng**: I have to do Preprocessing data. From the website where we get the data. This is a sales website, the creator of the website has too few tags to distinguish the drugs from each other. For projects where the ideation team will be looking for products that will have a lot of interest or sell a lot, the website does not provide the necessary attributes such as Rating and Sold.
# - **Hoàng Dinh**: During the process of working on the project, I found it challenging to formulate meaningful and insightful questions that would help users or businesses understand the current trends and situation. This would also aid in the data modeling process. The difficulty arose from the limited and not very diverse set of attributes we were able to collect. We have tried various approaches, but due to the nature of our chosen topic, we couldn't gather more useful attributes.
# - **Ngọc Linh**: I encountered several difficulties throughout the project that impacted my work and the team's progress. One major difficulty was identifying and analyzing relevant features from the data collected from the Long Chau Pharmacy website. The limited availability of meaningful attributes hindered our ability to ask insightful questions about the chosen topic. Additionally, the dataset posed challenges in finding a suitable model, lacking diversity and essential attributes.

# %% [markdown]
# ### **2. What have you learnt?**

# %% [markdown]
# - **Liên Hoa**: Through the project, I found myself understanding the basic sequence of steps in Data Science. At the same time, understanding more about the topic we chose. Basic skills such as preprocessing, visualization, and how to use basic training models. Finally, teamwork skills were also improved throughout the project.
# - **Duy Hưng**: After the project, I knew I have to know more in many different fields such as visualization, web development, and know data well. I learned about data processing, know what to do in a process.
# - **Hoàng Dinh**: Through this project, I have learned a great deal. I can now collect data for analysis in various ways. I understand how to apply attributes, formulate meaningful questions, and visualize them in a way that truly serves our ultimate goals. Additionally, I have learned many modeling algorithms and how to evaluate models to predict with a high degree of accuracy the things we need to explore, benefiting both businesses and consumers.
# - **Ngọc Linh**: Through this project, I gained a deeper understanding of the foundational steps involved in Data Science, from data preprocessing to visualization and applying basic training models. Additionally, I developed skills in formulating meaningful questions and effectively using collected attributes to derive insights. I also enhanced my knowledge of data collection techniques, various modeling algorithms, and their evaluation to ensure accurate predictions. Beyond technical skills, this project significantly improved my teamwork and collaboration abilities, allowing me to contribute effectively to the group's objectives.

# %% [markdown]
# ### **3. What would you do if you had more time?**

# %% [markdown]
# - We may get more referral information, process referral information, add more features, or use similar product information from other websites to supplement.
# - Introduce people to the website so that users can buy and evaluate, helping the group have more information.
